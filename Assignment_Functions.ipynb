# %% [markdown]
# **Functions Assignment**
#
# 1. What is the difference between a function and a method in Python?
# >> Functions are independent and doesn't belong to any object. While methods are defined inside a class and called by object they are defined under. Functions are useful when we have to reuse a code mutliple times. For example when we need to find out whether a number is even or not
#
#                def is_even(x):
#                        if x%2==0:
#                             return True
#                       else:
#                          return False
#
#
#  >>> While method is useful when we want to store and manage state radius and define a function such as area together.
#
#                class Circle:
#                       def __init__(self, radius):
#                           self.radius = radius
#
#                       def area(self):
#                           return 3.14 * self.radius * self.radius
#
#                 c1 = Circle(5)
#                 c2 = Circle(10)
#
#
#
#
# 2.  Explain the concept of function arguments and parameters in Python?
# >> Parameters are basically placeholders which are used while defining a function while arguments are the actual values passed to function while calling it.
# For example:
#               def square(num): #here num is a parameter
#                       return num**2
#               print(square(5)) # 5 is an argument
#               print(square(10)) #10 is an argument
#
# 3.  What are the different ways to define and call a function in Python?
# >> There are many ways you can define and call a function:
#      1. Defining using 'def' and calling by its name:
#
#               def say_hi(name):
#                         print("Hello",name)
#
#               print(say_hi("Shubham")) #Output: Hello, Shubham
#
#     2. Passing default values if no argument is given:
#
#               def say_hi(name="People"):
#                         return f" Hello, {name}"
#
#               print(say_hi()) #will return 'Hello, People'
#     3. Passing multiple arguments:
#
#               def sum_num(*num):
#                         return sum(num)
#
#               print(sum_num(2,3,4,5,6)) #Output: 20
#     4. Passing keyword arguments, we can pass dictionary or key-value pairs as arguments.
#
#               def employee_info(**kwargs):
#                       for key, value in kwargs.items():
#                         return f"{key}:{value}"
#
#             pint(employee_info(name="Shubh",position="Manager",contact=9234) #Output: name: Shubh position: Manager contact=9234
#
#     5. Defining Lambda function also known as anonymous function:
#
#                    square= lambda x: x**2
#                   print(square(3)) #Output: 9
#
#     6. Caling using map() or filter() function:
#
#                 square = list(map(lambda x: x**2, [2,5,3]))
#                 print(square) #Output: [4,25,9]
#
#                 even= list(filter(lambda x: x%2==0, [1,2,3,6]))
#                 print(even) #Output: [2,6]
#
#
# 4.  What is the purpose of the "return" statement in a Python function?
# >>  Return statement basically terminates the code while storing and returning the output of a function.
#
#                 def is_even(num):
#                       if num%2==0:
#                           return True
#                       else:
#                           return False
#
#                 print(is_even(10)) #Output: True
#                 #it will basically terminate the code as soon as the first condition is met and not move ahead to next line
#
#
# 5. What are iterators in Python and how do they differ from iterables?
# >>  Iterators are the object which are used to generate iteration. While iterables are the object which can be iterated using interators. You can use iterators to traverse through all the values of an interable. List, tuples, strings are example of iterables.
#
#               l1=[1,2,3,4] #iterable object
#               a= iter(l1) #creating interators using iter()
#               print(next(a)) #Output: 1
#               print(next(a)) #Output: 2
#
# 6. Explain the concept of generators in Python and how they are defined?
# >> Generators are the functions used to create an interator and uses yeild instead of return. These generators don't have to return all the values at once but using yield they can remember the current value and produce next value whenever asked using next.
#
#               def gen(l):
#                 for i in l:
#                 yield i
#
#               g=gen([1,2,3])
#               print(next(g)) #output: 1
#               print(nextt(g)) #output: 2
#
# 7. What are the advantages of using generators over regular functions?
# >> Generators are memory efficient and does not return all values at once but gives the value using next() when demanded. They only store the current value unlike regular functions which loops through all values.
#             #generator function
#             def gen(l):
#                 for i in l:
#                 yield i
#
#             g=gen([1,2,3])
#               print(next(g)) #output: 1
#               print(nextt(g)) #output: 2
#
#             #regular function
#             def reg(l):
#               for in l:
#                 print(i)
#             print(reg([1,2,3])) #output: 1,2,3
#
#
# 8. What is a lambda function in Python and when is it typically used?
# >> Lambda function also known as anonymous function which can have multiple arguments and but only one expression.They are mainly used when required do simple operations. They are also used as arguments for higher order functions such as map(), filter() or reduce().
#             #example of lambda function to perform simple operations
#             sq= lamda x: x**2 #to return square of a number
#
#             #used as an argument for higher order functions
#             sq_list=list(map(lamda x: x**2,[2,4,6]))
#
# 9. Explain the purpose and usage of the  `map()` function in Python?
# >> Map function is used to map or perform the operation or apply a function to each element of an iterable.Syntax of map function is
# map(function, iterable).
#
#           l=list(map(lambda x: x.upper(),["animal","tiger","lion"]))
#           print(l) #output: ['ANIMAL', 'TIGER', 'LION']
#
#
# 10.  What is the difference between  `map()`, `reduce()`, and `filter()` functions in Python?
# >> Map applies a function to an iterable and modifies elements of the iterable as per the function. It can applied to more than one iterables and return can be converted to an iterable like lists.
#
#                l=list(map(lambda x,y: x+y, l1,l2))
#                #sum of elements of l1 and l2
#
# >> Reduce applies a function cummulatively to each element starting from the first element and will return a single value instead of an iterable. It is takes two arguments a function and a single iterable. It is imported from func tools library.
#
#               cum_product=reduce(lambda x: x*y, [2,3,5,4])
#               #process of multiplying 2*3>>6*5>>30*4>>120
#
# >> Filter function is used to filter out and return the remaining as output on the basis of a condition. It return filter object can be converted to tuples or lists.
#
#               even=list(filter(lambda x: x%2==0, [1,2,3,4,5,6]))
#           #will return all the even from the list and will filter out odd
#
#
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list: [47,11,42,13]
# >> Reduce function commulatively applies a function to each elements but taking two elements at a time.
# >> As for sum operation using the list [47,11,42,13]
#
#               from functools import reduce
#               cum_sum=reduce(lambda x,y: x+y, [47,11,42,13]) #Output: 113
#
#
#
# ![20250402_211526.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Functions Practical Questions**

# %%
#1.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

l1=list(range(1,20))

def sum_even(l):
  sum_ev=0
  for i in l:
    if i%2==0:
      sum_ev+=i
  return sum_ev

print(sum_even(l1))
# Out:
# 90

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.

strng="Missisippi"

def rev_str(s):
  return s[::-1]

rev_str(strng)
# Out:
# 'ippisissiM'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

l2=[2,3,10,13,12,20]

def sq_list(l):
  return list(map(lambda x: x**2,l))

sq_list(l2)
# Out:
# [4, 9, 100, 169, 144, 400]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.

l3=list(range(1,201))
def prm(x):
  for i in x:
    if i<2:
      print(f"{i} is not a prime number")
    else:
      for j in range(2,i):
        if i%j==0:
          print(f"{i} is not a prime number")
          break
      else:
        print(f"{i} is a prime number")

prm(l3)
# Out:
# 1 is not a prime number
# 2 is a prime number
# 3 is a prime number
# 4 is not a prime number
# 5 is a prime number
# 6 is not a prime number
# 7 is a prime number
# 8 is not a prime number
# 9 is not a prime number
# 10 is not a prime number
# 11 is a prime number
# 12 is not a prime number
# 13 is a prime number
# 14 is not a prime number
# 15 is not a prime number
# 16 is not a prime number
# 17 is a prime number
# 18 is not a prime number
# 19 is a prime number
# 20 is not a prime number
# 21 is not a prime number
# 22 is not a prime number
# 23 is a prime number
# 24 is not a prime number
# 25 is not a prime number
# 26 is not a prime number
# 27 is not a prime number
# 28 is not a prime number
# 29 is a prime number
# 30 is not a prime number
# 31 is a prime number
# 32 is not a prime number
# 33 is not a prime number
# 34 is not a prime number
# 35 is not a prime number
# 36 is not a prime number
# 37 is a prime number
# 38 is not a prime number
# 39 is not a prime number
# ...

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

def fib(n):
    a, b = 0, 1
    for i in range(1,n+1):
      yield a
      a, b = b, a + b
f=fib(9)
for i in f:
  print(i)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def sq(n):
  for i in range(n+1):
    yield 2**i

s=sq(5)
for i in s:
  print(i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
#7.  Implement a generator function that reads a file line by line and yields each line as a string.

#concpet of reading a file line by line is not a part of function topic and wasn't taught in class or modules. Raised this question to pw
# team. So instead of this question I am using generator to return each element of a string

def gen(strg):
  for i in strg:
    yield i

g=gen("Data Analytics")

for i in g:
  print(i)
# Out:
# D
# a
# t
# a
#
# A
# n
# a
# l
# y
# t
# i
# c
# s

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple


lt=[(2,5,11,121),(10,9,7),(101,54,33,21,33),(11,2,4,7)]
sorted(lt,key= lambda lt: lt[1])
# Out:
# [(11, 2, 4, 7), (2, 5, 11, 121), (10, 9, 7), (101, 54, 33, 21, 33)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

temp_C=[10,3,37,100,45,25]
temp_F=list(map(lambda x: round(x*(9/5)+32,2),temp_C))
print(temp_F)
# Out:
# [50.0, 37.4, 98.6, 212.0, 113.0, 77.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

nm="NorthernHemisphere"
lst_cnst=list(filter(lambda x: x.lower() not in "aeiou",nm))
nm_after_filter=""
for i in lst_cnst:
  nm_after_filter+=i
print(nm_after_filter)
# Out:
# NrthrnHmsphr

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#11.
orderbook = [[34587, "Learning Python, Mark Lutz", 4, 40.95], [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],[88112, "Einführung in Python3, Bernd Klein", 3, 24.99] ]

list(map(lambda x:(x[0],x[2]*x[3] + (10 if x[2]*x[3] < 100 else 0)),orderbook))
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]

# %% [markdown]
# **Files, Exception Handling, Logging and Memory Management**
#
# 1. What is the difference between interpreted and compiled languages?
# >> Interpreted language such as Python or JavaScript doesn't need any compiler to translate the code to a machine readable code befor its run. Code can be executed line by line. While compiled language such as C and C++ requires a compilation step before its run. These programs are much faster but will run whole program at once.
#
# 2. What is exception handling in Python?
# >> Exception handling in python is way to handle errors or exception in a program preventing it from crashing during run. It is done using the keywords `try` and `except` where code is entered inside try block while any error or exception is handled using except block
#
# 3. What is the purpose of the finally block in exception handling?
# >> Finally block ensures that the code or program written inside will be executed even if the exception or error arises during program run. It done to close any file or free up resources at the end of the program.
#
# 4. What is logging in Python?
# >> Logging is like maintaing a record of any event happening. It tracks and stores any event occuring during program run. It is done for logging general info or troubleshooting programs.
#
# 5. What is the significance of the __del__ method in Python?
# >> `__del__` method is a special method used to delete or remove an object associated with a class.
#
# 6. What is the difference between import and from ... import in Python?
# >> Both are used to bring libraries or modules into the current program. Import is used when you want to import whole module and acess any function stored in it. While from is used to import sepcific functions stored in the module.
#
# 7. How can you handle multiple exceptions in Python?
# >> Multiple exceptions can be handled using two ways.
# One is using multiple exception block to define individual errors or exceptions.
#
#             try:
#               body of code
#             except Error1:
#               print(Error1)
#             except Error2:
#               print(Error2)
#
# The other is writing multiple actions inside a single exception block.
#
#           try:
#             body of code
#           except (Error1, Error2):
#             print("Error Occurred")
#
#
# 8. What is the purpose of the with statement when handling files in Python?
# >> With statement is used execute a code and free up resources after the code is run. Opening a file inside a with statement ensures that file is properly closed at the end of the code.
#
#           with open("file.txt","r") as f:
#             f.read()
#
# 9. What is the difference between multithreading and multiprocessing?
# >> Both are a ways to manage multiple tasks concurrently and speed up the execution of program. But multithreading is done to manage different pieces of tasks by dividing them into threads and running them currently in same memory space. While multiprocessing is a way to handle heavy and demanding tasks to be handled individualy by separate CPU cores for better performance and efficiency.
#
# 10. What are the advantages of using logging in a program?
# >> Logging is way to store and track a program events while a program is running. Logging helps to track errors and debug a program faster by maintaing sequence of events and state of the programa during the entire excution process. It can store all these events and erros into log files and databases to monitor or troubleshoot a program later. In short it makes your code more maintainable, traceable and production ready.
#
# 11. What is memory management in Python?
# >> Memory management refers to how python manages or allocates the memory space during the program run ensuring memory is managed efficiently and doesn't unnecessarily eatup limited resources.
#
# 12. What are the basic steps involved in exception handling in Python?
# >> Steps involved in exception handling in python are: First writing the risky code inside a try block. Then writing exception to handles errors that might lead to a program crash using except block. These two are mandatory to write. Next you can add an else block to run if no exception arises during run. In the end you can add a finally block to run even if the program enters exception block.
#
#         try:
#           divisor=int(input("Enter a number:"))
#           divide= 10/divisor
#         except Exception as e:
#           print(e)
#         else:
#           print(f"result:{divide}")
#         finally:
#           print("It will run always")
#
#
# 13. Why is memory management important in Python?
# >> Memory management is important to manage and allocate resources efficiently to a program especially when there are large set of computational heavy codes are written. This ensures that a program run doesn't lag the entire system and maintain overall performance.
#
# 14. What is the role of try and except in exception handling?
# >> Try and except are used to handle exceptions in python. Risky code or operation is written inside a try block and all the possible errors and how to deal with them are mentioned inside the excpet block. It helps to prevent system from crashing and return user friendly messages incase an exception arises.
#
# 15. How does Python's garbage collection system work?
# >> Python's garbage collection system free ups the memory not in use automatically so that it can be reused. Whenever an object is referenced it increases the refrence count once the refences is deleted and refrence count returns to zero the memory gets freed up automatically.
#
# 16. What is the purpose of the else block in exception handling?
# >> Else block is executed only when no error arises during program run. It is used to print the result if everything went smoothly.
#
# 17. What are the common logging levels in Python?
# >> There are five standard logging level in python: Lowest level is DEBUG used to store diagnotic information and during debugging. Then INFO used to store general information about the program and its processes during run. After that WARNING if something unexpected or any potential issues arises it used to store warning. Then comes ERROR which records serious issues or a failed operation during the program run. And the highest priority is CRITCIAL when the program stops running due to some serious errors.
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
# >> os.fork is a python module used for multiprocessing which is only available to Unix/Linux based systems. It requires manual control over process management. While multiprocessing is across platform module which automatically handles all the processes.
#
# 19. What is the importance of closing a file in Python?
# >> Closing a file is a best practice to ensure a file is properly written and all the resources could be freed up. It avoids any data corruption and ensure the help can be opened again in next run.
#
# 20. What is the difference between file.read() and file.readline() in Python?
# >> file.read() will read entire contents of a file or upto a sepcified bytes while file.readline will only read one line at a time and will read next line only when executed again.
#
# 21. What is the logging module in Python used for?
# >> The logging module in python is used to generate and store messages in a program. It helps in debugging and monitoring the program at each step giving flexibility to write custom messages for each level of logs
#
# 22. What is the os module in Python used for in file handling?
# >>os module helps in interacting with the operating system and perform various directory related tasks such as creating a directory, removing it, or accessing the list of files in a directory
#
# 23. What are the challenges associated with memory management in Python?
# >> Challenges associate with memory management are: Pyhton overhead which occupies more memory than other lower level languages. Refrence counting prevents refrence count of an object from reaching zero thus leading to memory leaks. Lack of manual control takes away control from developers to free up resources.
#
# 24. How do you raise an exception manually in Python?
# >> Exceptions can be manually raised in pyton using raise statement.
#
#
#      def check(num):
#        if num<0:
#         raise ValueError("Number should be positive.")
#       return num
#
# Other than this we can made custom exceptions as a child class of general Exception class in python and can raise them.
#
#
# 25. Why is it important to use multithreading in certain applications?
# >> Multithreading ensures that tasks could be performed concurrently while a program runs leading to bettor memory utilization and improved performance.

# %%
#1. How can you open a file for writing in Python and write a string to it?

with open("file_name.txt","w") as f:
  f.write("This my first line of code for this file")
  f.write("\nThis is the second line of the file.")
with open("file_name.txt","r") as f:
  print(f.read())
# Out:
# This my first line of code for this file
# This is the second line of the file.

# %%
#2. Write a Python program to read the contents of a file and print each line.

file=open("file_name.txt","r")

for i in file:
  print(i)

file.close()
# Out:
# This my first line of code for this file
#
# This is the second line of the file.

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading.

try:
  with open("file_na.txt","r") as f:
    print(f.read())
except FileNotFoundError as FNF:
  print("File not found:",FNF)
except Exception as e:
  print("Error!", e)
# Out:
# File not found: [Errno 2] No such file or directory: 'file_na.txt'

# %%
#4. Write a Python script that reads from one file and writes its content to another file.

def file_paster(file_to_read, file_to_write):
  with open(file_to_read,"r") as f1:
    file=f1.read()
  with open(file_to_write,"w") as f2:
    f2.write(file)


file_paster("file_name.txt","file_test.txt")
with open("file_test.txt","r") as f1:
    print(f1.read())
# Out:
# This my first line of code for this file
# This is the second line of the file.

# %%
#5. How would you catch and handle division by zero error in Python?

try:
  dividend=int(input("Enter the Dividend:"))
  divisor=int(input("Enter the Divisor:"))
  result=dividend/divisor
except ZeroDivisionError as zde:
  print("Division by zero is not possible:",zde)
except Exception as e:
  print(e)
else:
  print(f"The result of division is {result}")
# Out:
# Enter the Dividend:33
# Enter the Divisor:0
# Division by zero is not possible: division by zero

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging

logging.basicConfig(
    filename='div_error.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s')

def divide(a, b):
    try:
        result = a / b
        print(f"Result: {result}")
    except ZeroDivisionError as e:
        logging.error("Attempted to divide by zero", exc_info=True)
        print("Error: Division by zero is not allowed.")

num1 = 10
num2 = 0

divide(num1, num2)
# Out:
# ERROR:root:Attempted to divide by zero
# Traceback (most recent call last):
#   File "<ipython-input-44-72c2d43a99b3>", line 12, in divide
#     result = a / b
#              ~~^~~
# ZeroDivisionError: division by zero
# Error: Division by zero is not allowed.

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module.

import logging


logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s')

logging.debug("This is a DEBUG message.")
logging.info("This is an INFO message.")
logging.warning("This is a WARNING message.")
logging.error("This is an ERROR message.")
logging.critical("This is a CRITICAL message.")
# Out:
# WARNING:root:This is a WARNING message.
# ERROR:root:This is an ERROR message.
# CRITICAL:root:This is a CRITICAL message.

# %%
#8. Write a program to handle a file opening error using exception handling.

def file_to_read(filename):
    try:
        with open(filename, 'r') as file:
            contents = file.read()
            print("File contents:\n",contents)
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

file_to_read("file_.txt")
# Out:
# Error: The file 'file_.txt' was not found.

# %%
#9. How can you read a file line by line and store its content in a list in Python.

with open("file_test.txt","r") as f:
  file = f.readlines()

print(file)
# Out:
# ['This my first line of code for this file\n', 'This is the second line of the file.']

# %%
#10. How can you append data to an existing file in Python.

with open("file_test.txt","a") as f:
  f.write("\nAdding one more line.")


with open("file_test.txt","r") as f:
  file=f.read()
print(file)
# Out:
# This my first line of code for this file
# This is the second line of the file.
# Adding one more line.

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
di={"name":"Anna","home":"Raipur", "siblings":2}

def di_value(key):
  try:
    di[key]
  except KeyError as ke:
    print(f"Given key '{key}' not found")
  except Exception as e:
    print("Error:",e)
  else:
    print("The key-value pair is\n",key,":" ,di[key])

di_value("age")
# Out:
# Given key 'age' not found

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.


try:
  dividend=int(input("Enter the Dividend:"))
  divisor=int(input("Enter the Divisor:"))
  result=dividend/divisor
except ZeroDivisionError as zde:
  print("Division by zero is not possible:",zde)
except ValueError as ve:
  print("Invalid entry:",ve)
except Exception as e:
  print(e)
else:
  print(f"The result of division is {result}")
# Out:
# Enter the Dividend:33
# Enter the Divisor:e
# Invalid entry: invalid literal for int() with base 10: 'e'

# %%
#13. How would you check if a file exists before attempting to read it in Python.

import os

file_path = 'new_file.txt'

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        contents = file.read()
        print(contents)
else:
    print("File does not exist.")
# Out:
# File does not exist.

# %%
#14. Write a program that uses the logging module to log both informational and error messages.

import logging


logging.basicConfig(
    filename='new_log.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s')

def divide(a, b):
    logging.info(f"Attempting to divide {a} by {b}")
    try:
      result = a / b
      logging.info(f"Division successful: {a} / {b} = {result}")
      return result
    except ZeroDivisionError:
      logging.error("Error: Attempted to divide by zero", exc_info=True)
      return None
    except Exception:
      logging.error("Unknown error encountered", exc_info=True)
      return None


divide(10, 2)
divide(5, 0)
# Out:
# ERROR:root:Error: Attempted to divide by zero
# Traceback (most recent call last):
#   File "<ipython-input-81-8468b2f2c2d4>", line 14, in divide
#     result = a / b
#              ~~^~~
# ZeroDivisionError: division by zero

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty.

nf=open("nf.txt","w")
nf.close()

def read_file(file_name):
  try:
    with open(file_name,"r") as f:
      file= f.read()
  except FileNotFoundError:
    print("File doesn't exist")
  else:
    if file.strip()=="":
      print("Empty file")
    else:
      print(file)

read_file("nf.txt")
# Out:
# Empty file

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program.

import psutil
import os

def memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024

def example_function():
    print(f"Memory before: {memory_usage():.2f} MB")
    my_list = [i for i in range(1000000)]
    print(f"Memory after: {memory_usage():.2f} MB")

example_function()
# Out:
# Memory before: 171.20 MB
# Memory after: 198.26 MB

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line.

l=list(range(1,10))

def list_add(l):
  with open("num_list.txt","w") as f1:
    f1.write("")
  for i in l:
     with open("num_list.txt","a") as f2:
      f2.write(f"{i}\n")
  with open("num_list.txt","r") as f3:
    print(f3.read())

list_add(l)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB.

import logging
from logging.handlers import RotatingFileHandler


log_handler = RotatingFileHandler(
    "rot_log.log",
    maxBytes=1 * 1024 * 1024,
    backupCount=3)


formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
log_handler.setFormatter(formatter)


logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.addHandler(log_handler)


for i in range(1000):
    logger.info(f"This is log message number {i}")
# Out:
# INFO:root:This is log message number 0
# INFO:root:This is log message number 1
# INFO:root:This is log message number 2
# INFO:root:This is log message number 3
# INFO:root:This is log message number 4
# INFO:root:This is log message number 5
# INFO:root:This is log message number 6
# INFO:root:This is log message number 7
# INFO:root:This is log message number 8
# INFO:root:This is log message number 9
# INFO:root:This is log message number 10
# INFO:root:This is log message number 11
# INFO:root:This is log message number 12
# INFO:root:This is log message number 13
# INFO:root:This is log message number 14
# INFO:root:This is log message number 15
# INFO:root:This is log message number 16
# INFO:root:This is log message number 17
# INFO:root:This is log message number 18
# INFO:root:This is log message number 19
# INFO:root:This is log message number 20
# INFO:root:This is log message number 21
# INFO:root:This is log message number 22
# INFO:root:This is log message number 23
# ...

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block.

try:
  li=[{"name":"Johnny","age":10,"city":"Delhi"},{"name":"Shirin","age":23,"city":"Jersey"}]
  li[int(input("Enter a number:"))][input("Enter a key:")]
except KeyError:
  print("Key not found")
except IndexError as i:
  print("Index Error:",i)
except Exception as e:
  print(e)
# Out:
# Enter a number:0
# Enter a key:2
# Key not found

# %%
#20. How would you open a file and read its contents using a context manager in Python.

with open("file_test.txt","r") as f:
  file=f.read()
  print(file)
# Out:
# This my first line of code for this file
# This is the second line of the file.
# Adding one more line.

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

text="""Is it the same that we show there.
It appears so but we can't confirm until we get close to it. It looks scary.
Yeah but it is adventurous"""

with open("text_read.txt","w") as f:
  f.write(text)

def word_finder(word):
  with open("text_read.txt","r") as f:
    file=f.read().lower()
    print(f"The word '{word}' appears {file.count(word)} times in the file")

word_finder("it")
# Out:
# The word 'it' appears 5 times in the file

# %%
#22.  How can you check if a file is empty before attempting to read its contents.

nf=open("nf.txt","w")
nf.close()

def read_file(file_name):
  try:
    with open(file_name,"r") as f:
      file= f.read()
  except FileNotFoundError:
    print("File doesn't exist")
  else:
    if file.strip()=="":
      print("Empty file")
    else:
      print(file)

read_file("nf.txt")
# Out:
# Empty file

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.

import logging


logging.basicConfig(
    filename='file_handling_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def read_file(file_name):
    try:
        with open(file_name, 'r') as f:
            content = f.read()
            print("File Content:\n", content)
    except Exception as e:
        logging.error(f"Error reading file '{file_name}': {e}")

read_file("non_existent_file.txt")
# Out:
# ERROR:root:Error reading file 'non_existent_file.txt': [Errno 2] No such file or directory: 'non_existent_file.txt'
